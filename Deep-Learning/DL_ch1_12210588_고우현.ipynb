# %%
1+1
# Out:
# 2

# %%
a=[1,2,3,4,5]
print(a)
a[1:3]
# Out:
# [1, 2, 3, 4, 5]
# [2, 3]

# %%
import numpy as np
A = np.array([[1,2],[3,4]])

# %%
import numpy as np
import matplotlib.pyplot as pt
x = np.arange(0, 6, 0.1)
p = np.sin(x)
pt.plot(x,p)

# %%
import numpy as np
import matplotlib.pyplot as pt
pt.show()
y1 = np.sin(x)
y2 = np.cos(x)
pt.plot(x, y2,linestyle="--", label="sin")

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('dog.jpg')

plt.imshow(img)
plt.show()
